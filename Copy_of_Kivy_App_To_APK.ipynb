# %% [markdown]
# <a href="https://colab.research.google.com/github/shrestha7723/ML/blob/master/Copy_of_Kivy_App_To_APK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf sample_data/

# %%
# !pip install buildozer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting buildozer
#   Downloading buildozer-1.5.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: pexpect in /usr/local/lib/python3.10/dist-packages (from buildozer) (4.8.0)
# Collecting virtualenv (from buildozer)
#   Downloading virtualenv-20.23.1-py3-none-any.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 105.0 MB/s eta 0:00:00
# Collecting sh (from buildozer)
#   Downloading sh-2.0.4-py3-none-any.whl (38 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect->buildozer) (0.7.0)
# Collecting distlib<1,>=0.3.6 (from virtualenv->buildozer)
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 46.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock<4,>=3.12 in /usr/local/lib/python3.10/dist-packages (from virtualenv->buildozer) (3.12.0)
# Collecting platformdirs<4,>=3.5.1 (from virtualenv->buildozer)
#   Downloading platformdirs-3.5.3-py3-none-any.whl (15 kB)
# Installing collected packages: distlib, sh, platformdirs, virtualenv, buildozer
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.3.0
#     Uninstalling platformdirs-3.3.0:
#       Successfully uninstalled platformdirs-3.3.0
# Successfully installed buildozer-1.5.0 distlib-0.3.6 platformdirs-3.5.3 sh-2.0.4 virtualenv-20.23.1

# %%
#!pip install cython

# %%
# !sudo apt install -y git zip unzip openjdk-17-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip3 install --upgrade Cython==0.29.33 virtualenv  # the --user should be removed if you do this in a v
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# autoconf is already the newest version (2.69-11.1).
# autoconf set to manually installed.
# pkg-config is already the newest version (0.29.1-0ubuntu4).
# zip is already the newest version (3.0-11build1).
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# libncurses5-dev is already the newest version (6.2-0ubuntu2.1).
# libssl-dev is already the newest version (1.1.1f-1ubuntu2.19).
# unzip is already the newest version (6.0-25ubuntu1.1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# zlib1g-dev set to manually installed.
# libtinfo5 is already the newest version (6.2-0ubuntu2.1).
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libfontenc1 libxkbfile1 libxtst6 libxxf86dga1
#   openjdk-17-jdk-headless openjdk-17-jre openjdk-17-jre-headless
#   python-pip-whl python3-setuptools python3-wheel x11-utils
# Suggested packages:
#   libtool-doc gcj-jdk openjdk-17-demo openjdk-17-source visualvm libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   | fonts-wqy-zenhei fonts-indic python-setuptools-doc mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libffi-dev libfontenc1 libncursesw5-dev libtool
#   libxkbfile1 libxtst6 libxxf86dga1 openjdk-17-jdk openjdk-17-jdk-headless
#   openjdk-17-jre openjdk-17-jre-headless python-pip-whl python3-pip
#   python3-setuptools python3-wheel x11-utils
# 0 upgraded, 20 newly installed, 0 to remove and 15 not upgraded.
# Need to get 121 MB of archives.
# After this operation, 290 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu1 [12.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-utils amd64 7.7+5 [199 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libatk-wrapper-java all 0.37.1-1 [53.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libatk-wrapper-java-jni amd64 0.37.1-1 [45.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libncursesw5-dev amd64 6.2-0ubuntu2.1 [988 B]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 libtool all 2.4.6-14 [161 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 openjdk-17-jre-headless amd64 17.0.7+7~us1-0ubuntu1~20.04 [43.7 MB]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 openjdk-17-jre amd64 17.0.7+7~us1-0ubuntu1~20.04 [183 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 openjdk-17-jdk-headless amd64 17.0.7+7~us1-0ubuntu1~20.04 [71.2 MB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 openjdk-17-jdk amd64 17.0.7+7~us1-0ubuntu1~20.04 [10.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.9 [1,805 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.9 [231 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Fetched 121 MB in 1s (94.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 20.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../01-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../02-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../03-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../04-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../05-libxxf86dga1_2%3a1.1.5-0ubuntu1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../06-x11-utils_7.7+5_amd64.deb ...
# Unpacking x11-utils (7.7+5) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../07-libatk-wrapper-java_0.37.1-1_all.deb ...
# Unpacking libatk-wrapper-java (0.37.1-1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../08-libatk-wrapper-java-jni_0.37.1-1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.37.1-1) ...
# Selecting previously unselected package libncursesw5-dev:amd64.
# Preparing to unpack .../09-libncursesw5-dev_6.2-0ubuntu2.1_amd64.deb ...
# Unpacking libncursesw5-dev:amd64 (6.2-0ubuntu2.1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-14_all.deb ...
# Unpacking libtool (2.4.6-14) ...
# Selecting previously unselected package openjdk-17-jre-headless:amd64.
# Preparing to unpack .../11-openjdk-17-jre-headless_17.0.7+7~us1-0ubuntu1~20.04_amd64.deb ...
# Unpacking openjdk-17-jre-headless:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# Selecting previously unselected package openjdk-17-jre:amd64.
# Preparing to unpack .../12-openjdk-17-jre_17.0.7+7~us1-0ubuntu1~20.04_amd64.deb ...
# Unpacking openjdk-17-jre:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# Selecting previously unselected package openjdk-17-jdk-headless:amd64.
# Preparing to unpack .../13-openjdk-17-jdk-headless_17.0.7+7~us1-0ubuntu1~20.04_amd64.deb ...
# Unpacking openjdk-17-jdk-headless:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# Selecting previously unselected package openjdk-17-jdk:amd64.
# Preparing to unpack .../14-openjdk-17-jdk_17.0.7+7~us1-0ubuntu1~20.04_amd64.deb ...
# Unpacking openjdk-17-jdk:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# Selecting previously unselected package python-pip-whl.
# Preparing to unpack .../15-python-pip-whl_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.9) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../16-python3-setuptools_45.2.0-1ubuntu0.1_all.deb ...
# Unpacking python3-setuptools (45.2.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../17-python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../18-python3-pip_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.9) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../19-libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Setting up python3-setuptools (45.2.0-1ubuntu0.1) ...
# Setting up libncursesw5-dev:amd64 (6.2-0ubuntu2.1) ...
# Setting up libtool (2.4.6-14) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up openjdk-17-jre-headless:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/java to provide /usr/bin/java (java) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jpackage to provide /usr/bin/jpackage (jpackage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/keytool to provide /usr/bin/keytool (keytool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/rmiregistry to provide /usr/bin/rmiregistry (rmiregistry) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/lib/jexec to provide /usr/bin/jexec (jexec) in auto mode
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.9) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up openjdk-17-jre:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# Setting up openjdk-17-jdk-headless:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jar to provide /usr/bin/jar (jar) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jarsigner to provide /usr/bin/jarsigner (jarsigner) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javac to provide /usr/bin/javac (javac) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javadoc to provide /usr/bin/javadoc (javadoc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/javap to provide /usr/bin/javap (javap) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jcmd to provide /usr/bin/jcmd (jcmd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdb to provide /usr/bin/jdb (jdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdeprscan to provide /usr/bin/jdeprscan (jdeprscan) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jdeps to provide /usr/bin/jdeps (jdeps) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jfr to provide /usr/bin/jfr (jfr) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jimage to provide /usr/bin/jimage (jimage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jinfo to provide /usr/bin/jinfo (jinfo) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jlink to provide /usr/bin/jlink (jlink) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jmap to provide /usr/bin/jmap (jmap) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jmod to provide /usr/bin/jmod (jmod) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jps to provide /usr/bin/jps (jps) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jrunscript to provide /usr/bin/jrunscript (jrunscript) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jshell to provide /usr/bin/jshell (jshell) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstack to provide /usr/bin/jstack (jstack) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstat to provide /usr/bin/jstat (jstat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jstatd to provide /usr/bin/jstatd (jstatd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/serialver to provide /usr/bin/serialver (serialver) in auto mode
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jhsdb to provide /usr/bin/jhsdb (jhsdb) in auto mode
# Setting up python3-pip (20.0.2-5ubuntu1.9) ...
# Setting up x11-utils (7.7+5) ...
# Setting up libatk-wrapper-java (0.37.1-1) ...
# Setting up openjdk-17-jdk:amd64 (17.0.7+7~us1-0ubuntu1~20.04) ...
# update-alternatives: using /usr/lib/jvm/java-17-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Setting up libatk-wrapper-java-jni:amd64 (0.37.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Cython==0.29.33
#   Downloading Cython-0.29.33-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 62.3 MB/s eta 0:00:00
# Requirement already satisfied: virtualenv in /usr/local/lib/python3.10/dist-packages (20.23.1)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (0.3.6)
# Requirement already satisfied: filelock<4,>=3.12 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (3.12.0)
# Requirement already satisfied: platformdirs<4,>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv) (3.5.3)
# Installing collected packages: Cython
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.34
#     Uninstalling Cython-0.29.34:
#       Successfully uninstalled Cython-0.29.34
# Successfully installed Cython-0.29.33

# %%
# !pip install kivymd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kivymd
#   Downloading kivymd-1.1.1.tar.gz (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting kivy>=2.0.0 (from kivymd)
#   Downloading Kivy-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 64.9 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from kivymd) (8.4.0)
# Collecting Kivy-Garden>=0.1.4 (from kivy>=2.0.0->kivymd)
#   Downloading Kivy_Garden-0.1.5-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: docutils in /usr/local/lib/python3.10/dist-packages (from kivy>=2.0.0->kivymd) (0.16)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from kivy>=2.0.0->kivymd) (2.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from Kivy-Garden>=0.1.4->kivy>=2.0.0->kivymd) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy>=2.0.0->kivymd) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy>=2.0.0->kivymd) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy>=2.0.0->kivymd) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->Kivy-Garden>=0.1.4->kivy>=2.0.0->kivymd) (3.4)
# Building wheels for collected packages: kivymd
#   Building wheel for kivymd (pyproject.toml) ... done
#   Created wheel for kivymd: filename=kivymd-1.1.1-py3-none-any.whl size=2194082 sha256=a699cf04f4e1d7bfa2e3eda38e0b5dc5b622c7c83b704547f47f48196068d654
#   Stored in directory: /root/.cache/pip/wheels/12/d9/fa/2df584e3f57d3d9c57adf55edbe7791f7fa97522d1febe8ee0
# Successfully built kivymd
# Installing collected packages: Kivy-Garden, kivy, kivymd
# Successfully installed Kivy-Garden-0.1.5 kivy-2.2.1 kivymd-1.1.1

# %%
# !sudo apt-get install -y \
    python3-pip \
    build-essential \
    git \
    python3 \
    python3-dev \
    ffmpeg \
    libsdl2-dev \
    libsdl2-image-dev \
    libsdl2-mixer-dev \
    libsdl2-ttf-dev \
    libportmidi-dev \
    libswscale-dev \
    libavformat-dev \
    libavcodec-dev \
    zlib1g-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3 is already the newest version (3.8.2-0ubuntu2).
# python3 set to manually installed.
# python3-dev is already the newest version (3.8.2-0ubuntu2).
# python3-dev set to manually installed.
# build-essential is already the newest version (12.8ubuntu1.1).
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:4.2.7-0ubuntu0.1).
# libswscale-dev set to manually installed.
# python3-pip is already the newest version (20.0.2-5ubuntu1.9).
# The following additional packages will be installed:
#   gir1.2-ibus-1.0 libblkid-dev libblkid1 libdbus-1-dev libegl1-mesa-dev
#   libfluidsynth2 libgl1-mesa-dev libgles-dev libgles1 libgles2-mesa-dev
#   libglib2.0-dev libglib2.0-dev-bin libglvnd-dev libibus-1.0-5 libibus-1.0-dev
#   libinstpatch-1.0-2 libmodplug1 libmount-dev libmount1 libopengl-dev
#   libopusfile0 libportmidi0 libpulse-dev libpulse-mainloop-glib0
#   libsdl2-image-2.0-0 libsdl2-mixer-2.0-0 libsdl2-ttf-2.0-0 libselinux1-dev
#   libsepol1-dev libsndio-dev libudev-dev libudev1 libwayland-bin
#   libwayland-dev libxcursor-dev libxfixes-dev libxi-dev libxinerama-dev
#   libxkbcommon-dev libxrandr-dev libxv-dev libxxf86vm-dev timgm6mb-soundfont
#   x11proto-input-dev x11proto-randr-dev x11proto-xf86vidmode-dev
#   x11proto-xinerama-dev
# Suggested packages:
#   libgirepository1.0-dev libglib2.0-doc libgdk-pixbuf2.0-bin
#   | libgdk-pixbuf2.0-dev libxml2-utils libwayland-doc fluid-soundfont-gm
#   fluidsynth timidity musescore
# The following NEW packages will be installed:
#   gir1.2-ibus-1.0 libblkid-dev libdbus-1-dev libegl1-mesa-dev libfluidsynth2
#   libgl1-mesa-dev libgles-dev libgles1 libgles2-mesa-dev libglib2.0-dev
#   libglib2.0-dev-bin libglvnd-dev libibus-1.0-5 libibus-1.0-dev
#   libinstpatch-1.0-2 libmodplug1 libmount-dev libopengl-dev libopusfile0
#   libportmidi-dev libportmidi0 libpulse-dev libpulse-mainloop-glib0
#   libsdl2-dev libsdl2-image-2.0-0 libsdl2-image-dev libsdl2-mixer-2.0-0
#   libsdl2-mixer-dev libsdl2-ttf-2.0-0 libsdl2-ttf-dev libselinux1-dev
#   libsepol1-dev libsndio-dev libudev-dev libwayland-bin libwayland-dev
#   libxcursor-dev libxfixes-dev libxi-dev libxinerama-dev libxkbcommon-dev
#   libxrandr-dev libxv-dev libxxf86vm-dev timgm6mb-soundfont x11proto-input-dev
#   x11proto-randr-dev x11proto-xf86vidmode-dev x11proto-xinerama-dev
# The following packages will be upgraded:
#   libblkid1 libmount1 libudev1
# 3 upgraded, 49 newly installed, 0 to remove and 12 not upgraded.
# Need to get 11.2 MB of archives.
# After this operation, 38.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid1 amd64 2.34-0.1ubuntu9.4 [137 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount1 amd64 2.34-0.1ubuntu9.4 [150 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev1 amd64 245.4-4ubuntu3.22 [75.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libibus-1.0-5 amd64 1.5.22-2ubuntu2.1 [153 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.22-2ubuntu2.1 [65.9 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libdbus-1-dev amd64 1.12.16-2ubuntu2.3 [167 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles1 amd64 1.3.2-1~ubuntu0.20.04.2 [10.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles-dev amd64 1.3.2-1~ubuntu0.20.04.2 [47.9 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libopengl-dev amd64 1.3.2-1~ubuntu0.20.04.2 [3,584 B]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglvnd-dev amd64 1.3.2-1~ubuntu0.20.04.2 [11.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libegl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [7,760 B]
# Get:12 http://archive.ubuntu.com/ubuntu focal/universe amd64 libinstpatch-1.0-2 amd64 1.1.2-2build1 [238 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/universe amd64 timgm6mb-soundfont all 1.3-3 [5,420 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/universe amd64 libfluidsynth2 amd64 2.1.1-2 [198 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgles2-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,424 B]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev-bin amd64 2.64.6-1~ubuntu20.04.6 [109 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid-dev amd64 2.34-0.1ubuntu9.4 [167 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount-dev amd64 2.34-0.1ubuntu9.4 [177 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1-dev amd64 3.0-1ubuntu0.1 [325 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libselinux1-dev amd64 3.0-1build2 [151 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev amd64 2.64.6-1~ubuntu20.04.6 [1,507 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libibus-1.0-dev amd64 1.5.22-2ubuntu2.1 [179 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/universe amd64 libmodplug1 amd64 1:0.8.9.0-2build1 [150 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopusfile0 amd64 0.9+20170913-1build1 [38.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportmidi0 amd64 1:217-6 [17.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportmidi-dev amd64 1:217-6 [52.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpulse-mainloop-glib0 amd64 1:13.99.1-1ubuntu3.13 [11.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpulse-dev amd64 1:13.99.1-1ubuntu3.13 [72.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgl1-mesa-dev amd64 21.2.6-0ubuntu0.1~20.04.2 [6,420 B]
# Get:30 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsndio-dev amd64 1.5.0-3 [13.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libudev-dev amd64 245.4-4ubuntu3.22 [19.7 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-bin amd64 1.18.0-1ubuntu0.1 [20.2 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libwayland-dev amd64 1.18.0-1ubuntu0.1 [64.6 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfixes-dev amd64 1:5.0.3-2 [11.4 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcursor-dev amd64 1:1.2.0-2 [26.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-input-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 libxi-dev amd64 2:1.7.10-0ubuntu1 [187 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xinerama-dev all 2019.2-1ubuntu1 [2,628 B]
# Get:39 http://archive.ubuntu.com/ubuntu focal/main amd64 libxinerama-dev amd64 2:1.1.4-2 [7,896 B]
# Get:40 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbcommon-dev amd64 0.10.0-1 [45.4 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-randr-dev all 2019.2-1ubuntu1 [2,620 B]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrandr-dev amd64 2:1.5.2-0ubuntu1 [25.0 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xf86vidmode-dev all 2019.2-1ubuntu1 [2,624 B]
# Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build1 [13.3 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-dev amd64 2.0.10+dfsg1-3 [718 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-image-2.0-0 amd64 2.0.5+dfsg1-2 [63.8 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-image-dev amd64 2.0.5+dfsg1-2 [69.4 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-mixer-2.0-0 amd64 2.0.4+dfsg1-2build1 [60.2 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-mixer-dev amd64 2.0.4+dfsg1-2build1 [75.7 kB]
# Get:51 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-ttf-2.0-0 amd64 2.0.15+dfsg1-1 [15.6 kB]
# Get:52 http://archive.ubuntu.com/ubuntu focal/universe amd64 libsdl2-ttf-dev amd64 2.0.15+dfsg1-1 [20.5 kB]
# Fetched 11.2 MB in 1s (17.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 52.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 124089 files and directories currently installed.)
# Preparing to unpack .../libblkid1_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libblkid1:amd64 (2.34-0.1ubuntu9.4) over (2.34-0.1ubuntu9.3) ...
# Setting up libblkid1:amd64 (2.34-0.1ubuntu9.4) ...
# (Reading database ... 124089 files and directories currently installed.)
# Preparing to unpack .../libmount1_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libmount1:amd64 (2.34-0.1ubuntu9.4) over (2.34-0.1ubuntu9.3) ...
# Setting up libmount1:amd64 (2.34-0.1ubuntu9.4) ...
# (Reading database ... 124089 files and directories currently installed.)
# Preparing to unpack .../libudev1_245.4-4ubuntu3.22_amd64.deb ...
# Unpacking libudev1:amd64 (245.4-4ubuntu3.22) over (245.4-4ubuntu3.21) ...
# Setting up libudev1:amd64 (245.4-4ubuntu3.22) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# (Reading database ... 124089 files and directories currently installed.)
# Preparing to unpack .../00-libibus-1.0-5_1.5.22-2ubuntu2.1_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.22-2ubuntu2.1) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../01-gir1.2-ibus-1.0_1.5.22-2ubuntu2.1_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.22-2ubuntu2.1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../02-libdbus-1-dev_1.12.16-2ubuntu2.3_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.16-2ubuntu2.3) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../03-libgles1_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgles1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../04-libgles-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../05-libopengl-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../06-libglvnd-dev_1.3.2-1~ubuntu0.20.04.2_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../07-libegl1-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../08-libinstpatch-1.0-2_1.1.2-2build1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.2-2build1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../09-timgm6mb-soundfont_1.3-3_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-3) ...
# Selecting previously unselected package libfluidsynth2:amd64.
# Preparing to unpack .../10-libfluidsynth2_2.1.1-2_amd64.deb ...
# Unpacking libfluidsynth2:amd64 (2.1.1-2) ...
# Selecting previously unselected package libgles2-mesa-dev:amd64.
# Preparing to unpack .../11-libgles2-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgles2-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../12-libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../13-libblkid-dev_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../14-libmount-dev_2.34-0.1ubuntu9.4_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../15-libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../16-libselinux1-dev_3.0-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../17-libglib2.0-dev_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../18-libibus-1.0-dev_1.5.22-2ubuntu2.1_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.22-2ubuntu2.1) ...
# Selecting previously unselected package libmodplug1:amd64.
# Preparing to unpack .../19-libmodplug1_1%3a0.8.9.0-2build1_amd64.deb ...
# Unpacking libmodplug1:amd64 (1:0.8.9.0-2build1) ...
# Selecting previously unselected package libopusfile0.
# Preparing to unpack .../20-libopusfile0_0.9+20170913-1build1_amd64.deb ...
# Unpacking libopusfile0 (0.9+20170913-1build1) ...
# Selecting previously unselected package libportmidi0:amd64.
# Preparing to unpack .../21-libportmidi0_1%3a217-6_amd64.deb ...
# Unpacking libportmidi0:amd64 (1:217-6) ...
# Selecting previously unselected package libportmidi-dev.
# Preparing to unpack .../22-libportmidi-dev_1%3a217-6_amd64.deb ...
# Unpacking libportmidi-dev (1:217-6) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../23-libpulse-mainloop-glib0_1%3a13.99.1-1ubuntu3.13_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:13.99.1-1ubuntu3.13) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../24-libpulse-dev_1%3a13.99.1-1ubuntu3.13_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:13.99.1-1ubuntu3.13) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../25-libgl1-mesa-dev_21.2.6-0ubuntu0.1~20.04.2_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../26-libsndio-dev_1.5.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.5.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../27-libudev-dev_245.4-4ubuntu3.22_amd64.deb ...
# Unpacking libudev-dev:amd64 (245.4-4ubuntu3.22) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../28-libwayland-bin_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../29-libwayland-dev_1.18.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.18.0-1ubuntu0.1) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../30-libxfixes-dev_1%3a5.0.3-2_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:5.0.3-2) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../31-libxcursor-dev_1%3a1.2.0-2_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2) ...
# Selecting previously unselected package x11proto-input-dev.
# Preparing to unpack .../32-x11proto-input-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-input-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../33-libxi-dev_2%3a1.7.10-0ubuntu1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../34-x11proto-xinerama-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../35-libxinerama-dev_2%3a1.1.4-2_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-2) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../36-libxkbcommon-dev_0.10.0-1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.10.0-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../37-x11proto-randr-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-randr-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../38-libxrandr-dev_2%3a1.5.2-0ubuntu1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../39-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package x11proto-xf86vidmode-dev.
# Preparing to unpack .../40-x11proto-xf86vidmode-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xf86vidmode-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../41-libxxf86vm-dev_1%3a1.1.4-1build1_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1build1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../42-libsdl2-dev_2.0.10+dfsg1-3_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.10+dfsg1-3) ...
# Selecting previously unselected package libsdl2-image-2.0-0:amd64.
# Preparing to unpack .../43-libsdl2-image-2.0-0_2.0.5+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-image-2.0-0:amd64 (2.0.5+dfsg1-2) ...
# Selecting previously unselected package libsdl2-image-dev:amd64.
# Preparing to unpack .../44-libsdl2-image-dev_2.0.5+dfsg1-2_amd64.deb ...
# Unpacking libsdl2-image-dev:amd64 (2.0.5+dfsg1-2) ...
# Selecting previously unselected package libsdl2-mixer-2.0-0:amd64.
# Preparing to unpack .../45-libsdl2-mixer-2.0-0_2.0.4+dfsg1-2build1_amd64.deb ...
# Unpacking libsdl2-mixer-2.0-0:amd64 (2.0.4+dfsg1-2build1) ...
# Selecting previously unselected package libsdl2-mixer-dev:amd64.
# Preparing to unpack .../46-libsdl2-mixer-dev_2.0.4+dfsg1-2build1_amd64.deb ...
# Unpacking libsdl2-mixer-dev:amd64 (2.0.4+dfsg1-2build1) ...
# Selecting previously unselected package libsdl2-ttf-2.0-0:amd64.
# Preparing to unpack .../47-libsdl2-ttf-2.0-0_2.0.15+dfsg1-1_amd64.deb ...
# Unpacking libsdl2-ttf-2.0-0:amd64 (2.0.15+dfsg1-1) ...
# Selecting previously unselected package libsdl2-ttf-dev:amd64.
# Preparing to unpack .../48-libsdl2-ttf-dev_2.0.15+dfsg1-1_amd64.deb ...
# Unpacking libsdl2-ttf-dev:amd64 (2.0.15+dfsg1-1) ...
# Setting up libsdl2-image-2.0-0:amd64 (2.0.5+dfsg1-2) ...
# Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-2build1) ...
# Setting up libsndio-dev:amd64 (1.5.0-3) ...
# Setting up x11proto-randr-dev (2019.2-1ubuntu1) ...
# Setting up libxkbcommon-dev:amd64 (0.10.0-1) ...
# Setting up libibus-1.0-5:amd64 (1.5.22-2ubuntu2.1) ...
# Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Setting up x11proto-xinerama-dev (2019.2-1ubuntu1) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-2) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up libwayland-bin (1.18.0-1ubuntu0.1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-0ubuntu1) ...
# Setting up libdbus-1-dev:amd64 (1.12.16-2ubuntu2.3) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:13.99.1-1ubuntu3.13) ...
# Setting up libgles1:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libportmidi0:amd64 (1:217-6) ...
# Setting up x11proto-input-dev (2019.2-1ubuntu1) ...
# Setting up libudev-dev:amd64 (245.4-4ubuntu3.22) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-2) ...
# Setting up x11proto-xf86vidmode-dev (2019.2-1ubuntu1) ...
# Setting up libportmidi-dev (1:217-6) ...
# Setting up libsdl2-ttf-2.0-0:amd64 (2.0.15+dfsg1-1) ...
# Setting up libopengl-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libgles-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libxi-dev:amd64 (2:1.7.10-0ubuntu1) ...
# Setting up timgm6mb-soundfont (1.3-3) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up gir1.2-ibus-1.0:amd64 (1.5.22-2ubuntu2.1) ...
# Setting up libopusfile0 (0.9+20170913-1build1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.2-2build1) ...
# Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.4) ...
# Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1build1) ...
# Setting up libglvnd-dev:amd64 (1.3.2-1~ubuntu0.20.04.2) ...
# Setting up libwayland-dev:amd64 (1.18.0-1ubuntu0.1) ...
# Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Setting up libgl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libfluidsynth2:amd64 (2.1.1-2) ...
# Setting up libegl1-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libgles2-mesa-dev:amd64 (21.2.6-0ubuntu0.1~20.04.2) ...
# Setting up libsdl2-mixer-2.0-0:amd64 (2.0.4+dfsg1-2build1) ...
# Processing triggers for libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Setting up libibus-1.0-dev:amd64 (1.5.22-2ubuntu2.1) ...
# Setting up libpulse-dev:amd64 (1:13.99.1-1ubuntu3.13) ...
# Setting up libsdl2-dev:amd64 (2.0.10+dfsg1-3) ...
# Setting up libsdl2-ttf-dev:amd64 (2.0.15+dfsg1-1) ...
# Setting up libsdl2-mixer-dev:amd64 (2.0.4+dfsg1-2build1) ...
# Setting up libsdl2-image-dev:amd64 (2.0.5+dfsg1-2) ...

# %%
# !sudo apt-get install -y \
    libgstreamer1.0 \
    gstreamer1.0-plugins-base \
    gstreamer1.0-plugins-good
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libgstreamer1.0-dev' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0-dbg' for regex 'libgstreamer1.0'
# Note, selecting 'libgstreamer1.0-0' for regex 'libgstreamer1.0'
# libgstreamer1.0-0 is already the newest version (1.16.3-0ubuntu1.1).
# libgstreamer1.0-0 set to manually installed.
# The following additional packages will be installed:
#   autopoint debhelper dh-autoreconf dh-strip-nondeterminism dwz gettext
#   gettext-base gir1.2-gstreamer-1.0 gstreamer1.0-x intltool-debian libaa1
#   libarchive-cpio-perl libarchive-zip-perl libcdparanoia0 libcroco3
#   libdebhelper-perl libdv4 libfile-stripnondeterminism-perl
#   libgstreamer-plugins-good1.0-0 libmail-sendmail-perl libshout3
#   libsub-override-perl libsys-hostname-long-perl libtag1v5 libtag1v5-vanilla
#   libv4l-0 libv4lconvert0 libvisual-0.4-0 po-debconf
# Suggested packages:
#   dh-make gettext-doc libasprintf-dev libgettextpo-dev gvfs libdv-bin
#   oss-compat gstreamer1.0-doc libvisual-0.4-plugins libmail-box-perl
# The following NEW packages will be installed:
#   autopoint debhelper dh-autoreconf dh-strip-nondeterminism dwz gettext
#   gettext-base gir1.2-gstreamer-1.0 gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x intltool-debian libaa1
#   libarchive-cpio-perl libarchive-zip-perl libcdparanoia0 libcroco3
#   libdebhelper-perl libdv4 libfile-stripnondeterminism-perl
#   libgstreamer-plugins-good1.0-0 libgstreamer1.0-0-dbg libgstreamer1.0-dev
#   libmail-sendmail-perl libshout3 libsub-override-perl
#   libsys-hostname-long-perl libtag1v5 libtag1v5-vanilla libv4l-0
#   libv4lconvert0 libvisual-0.4-0 po-debconf
# 0 upgraded, 33 newly installed, 0 to remove and 12 not upgraded.
# Need to get 10.1 MB of archives.
# After this operation, 34.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext-base amd64 0.19.8.1-10build1 [50.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 autopoint all 0.19.8.1-10build1 [412 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 dh-autoreconf all 19 [16.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libdebhelper-perl all 12.10ubuntu1 [62.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 libarchive-zip-perl all 1.67-2 [90.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libsub-override-perl all 0.09-2 [9,532 B]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libfile-stripnondeterminism-perl all 1.7.0-1 [15.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 dh-strip-nondeterminism all 1.7.0-1 [5,228 B]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 dwz amd64 0.13-5 [151 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libcroco3 amd64 0.6.13-1 [82.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 gettext amd64 0.19.8.1-10build1 [895 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal/main amd64 intltool-debian all 0.35.0+20060710.5 [24.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/main amd64 po-debconf all 1.0.21 [233 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 debhelper all 12.10ubuntu1 [877 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gir1.2-gstreamer-1.0 amd64 1.16.3-0ubuntu1.1 [72.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 libvisual-0.4-0 amd64 0.4.0-17 [99.8 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-base amd64 1.16.3-0ubuntu1.1 [620 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libaa1 amd64 1.4p5-46 [47.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 libdv4 amd64 1.0.0-12 [58.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.16.3-0ubuntu1.1 [68.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libshout3 amd64 2.4.3-1 [50.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-0.3ubuntu2 [280 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-0.3ubuntu2 [11.0 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4lconvert0 amd64 1.18.0-2build1 [76.5 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libv4l-0 amd64 1.18.0-2build1 [41.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-plugins-good amd64 1.16.3-0ubuntu1.1 [1,745 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 gstreamer1.0-x amd64 1.16.3-0ubuntu1.1 [74.7 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:30 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer1.0-dev amd64 1.16.3-0ubuntu1.1 [484 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgstreamer1.0-0-dbg amd64 1.16.3-0ubuntu1.1 [3,346 kB]
# Fetched 10.1 MB in 0s (21.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 33.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package gettext-base.
# (Reading database ... 125556 files and directories currently installed.)
# Preparing to unpack .../00-gettext-base_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-10build1) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../01-autopoint_0.19.8.1-10build1_all.deb ...
# Unpacking autopoint (0.19.8.1-10build1) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../02-dh-autoreconf_19_all.deb ...
# Unpacking dh-autoreconf (19) ...
# Selecting previously unselected package libdebhelper-perl.
# Preparing to unpack .../03-libdebhelper-perl_12.10ubuntu1_all.deb ...
# Unpacking libdebhelper-perl (12.10ubuntu1) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../04-libarchive-zip-perl_1.67-2_all.deb ...
# Unpacking libarchive-zip-perl (1.67-2) ...
# Selecting previously unselected package libsub-override-perl.
# Preparing to unpack .../05-libsub-override-perl_0.09-2_all.deb ...
# Unpacking libsub-override-perl (0.09-2) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../06-libfile-stripnondeterminism-perl_1.7.0-1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (1.7.0-1) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../07-dh-strip-nondeterminism_1.7.0-1_all.deb ...
# Unpacking dh-strip-nondeterminism (1.7.0-1) ...
# Selecting previously unselected package dwz.
# Preparing to unpack .../08-dwz_0.13-5_amd64.deb ...
# Unpacking dwz (0.13-5) ...
# Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../09-libcroco3_0.6.13-1_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.13-1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../10-gettext_0.19.8.1-10build1_amd64.deb ...
# Unpacking gettext (0.19.8.1-10build1) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../11-intltool-debian_0.35.0+20060710.5_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.5) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../12-po-debconf_1.0.21_all.deb ...
# Unpacking po-debconf (1.0.21) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../13-debhelper_12.10ubuntu1_all.deb ...
# Unpacking debhelper (12.10ubuntu1) ...
# Selecting previously unselected package gir1.2-gstreamer-1.0:amd64.
# Preparing to unpack .../14-gir1.2-gstreamer-1.0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-gstreamer-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../15-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../16-libvisual-0.4-0_0.4.0-17_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../17-gstreamer1.0-plugins-base_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../18-libaa1_1.4p5-46_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-46) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../19-libdv4_1.0.0-12_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-12) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../20-libgstreamer-plugins-good1.0-0_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../21-libshout3_2.4.3-1_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.3-1) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../22-libtag1v5-vanilla_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../23-libtag1v5_1.11.1+dfsg.1-0.3ubuntu2_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../24-libv4lconvert0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../25-libv4l-0_1.18.0-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.18.0-2build1) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../26-gstreamer1.0-plugins-good_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../27-gstreamer1.0-x_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../28-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libgstreamer1.0-dev:amd64.
# Preparing to unpack .../29-libgstreamer1.0-dev_1.16.3-0ubuntu1.1_amd64.deb ...
# Adding 'diversion of /usr/bin/dh_gstscancodecs to /usr/bin/dh_gstscancodecs-gst0.10 by libgstreamer1.0-dev'
# Adding 'diversion of /usr/share/man/man1/dh_gstscancodecs.1.gz to /usr/share/man/man1/dh_gstscancodecs.1.gz-gst0.10 by libgstreamer1.0-dev'
# Unpacking libgstreamer1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../30-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../31-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libgstreamer1.0-0-dbg:amd64.
# Preparing to unpack .../32-libgstreamer1.0-0-dbg_1.16.3-0ubuntu1.1_amd64.deb ...
# Unpacking libgstreamer1.0-0-dbg:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up gir1.2-gstreamer-1.0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up gstreamer1.0-x:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17) ...
# Setting up libgstreamer1.0-dev:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libarchive-zip-perl (1.67-2) ...
# Setting up libdebhelper-perl (12.10ubuntu1) ...
# Setting up gettext-base (0.19.8.1-10build1) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libshout3:amd64 (2.4.3-1) ...
# Setting up autopoint (0.19.8.1-10build1) ...
# Setting up libcroco3:amd64 (0.6.13-1) ...
# Setting up dwz (0.13-5) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.3ubuntu2) ...
# Setting up libdv4:amd64 (1.0.0-12) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up libv4lconvert0:amd64 (1.18.0-2build1) ...
# Setting up libsub-override-perl (0.09-2) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libgstreamer1.0-0-dbg:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up libaa1:amd64 (1.4p5-46) ...
# Setting up libfile-stripnondeterminism-perl (1.7.0-1) ...
# Setting up gettext (0.19.8.1-10build1) ...
# Setting up intltool-debian (0.35.0+20060710.5) ...
# Setting up libv4l-0:amd64 (1.18.0-2build1) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up dh-strip-nondeterminism (1.7.0-1) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.16.3-0ubuntu1.1) ...
# Setting up po-debconf (1.0.21) ...
# Setting up dh-autoreconf (19) ...
# Setting up debhelper (12.10ubuntu1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...

# %%
# !sudo apt-get install libffi7
# !sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi7
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libffi7 is already the newest version (3.3-4).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# bzip2 is already the newest version (1.0.8-2).
# libbz2-dev is already the newest version (1.0.8-2).
# libbz2-dev set to manually installed.
# libffi-dev is already the newest version (3.3-4).
# libffi7 is already the newest version (3.3-4).
# libreadline-dev is already the newest version (8.0-4).
# libreadline-dev set to manually installed.
# build-essential is already the newest version (12.8ubuntu1.1).
# liblzma-dev is already the newest version (5.2.4-1ubuntu1.1).
# liblzma-dev set to manually installed.
# libncursesw5-dev is already the newest version (6.2-0ubuntu2.1).
# libsqlite3-dev is already the newest version (3.31.1-4ubuntu0.5).
# libsqlite3-dev set to manually installed.
# libssl-dev is already the newest version (1.1.1f-1ubuntu2.19).
# openssl is already the newest version (1.1.1f-1ubuntu2.19).
# openssl set to manually installed.
# uuid-dev is already the newest version (2.34-0.1ubuntu9.4).
# uuid-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# Suggested packages:
#   sqlite3-doc
# The following NEW packages will be installed:
#   libgdbm-compat-dev libgdbm-dev sqlite3
# 0 upgraded, 3 newly installed, 0 to remove and 12 not upgraded.
# Need to get 947 kB of archives.
# After this operation, 3,053 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libgdbm-compat-dev amd64 1.18.1-5 [3,388 B]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libgdbm-dev amd64 1.18.1-5 [83.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 sqlite3 amd64 3.31.1-4ubuntu0.5 [860 kB]
# Fetched 947 kB in 0s (7,119 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgdbm-compat-dev.
# (Reading database ... 126898 files and directories currently installed.)
# Preparing to unpack .../libgdbm-compat-dev_1.18.1-5_amd64.deb ...
# Unpacking libgdbm-compat-dev (1.18.1-5) ...
# Selecting previously unselected package libgdbm-dev:amd64.
# Preparing to unpack .../libgdbm-dev_1.18.1-5_amd64.deb ...
# Unpacking libgdbm-dev:amd64 (1.18.1-5) ...
# Selecting previously unselected package sqlite3.
# Preparing to unpack .../sqlite3_3.31.1-4ubuntu0.5_amd64.deb ...
# Unpacking sqlite3 (3.31.1-4ubuntu0.5) ...
# Setting up libgdbm-compat-dev (1.18.1-5) ...
# Setting up libgdbm-dev:amd64 (1.18.1-5) ...
# Setting up sqlite3 (3.31.1-4ubuntu0.5) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
#!sudo apt-get install build-essential libsqlite3-dev sqlite3 bzip2 libbz2-dev zlib1g-dev libssl-dev openssl libgdbm-dev libgdbm-compat-dev liblzma-dev libreadline-dev libncursesw5-dev libffi-dev uuid-dev libffi7

# %%
# !sudo apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libffi-dev is already the newest version (3.3-4).
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.

# %%
# !yes | buildozer android clean
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? # Ensure build layout
# # Create directory /root/.buildozer
# # Create directory /root/.buildozer/cache
# # Create directory /content/.buildozer
# # Create directory /content/bin
# # Create directory /content/.buildozer/applibs
# # Create directory /root/.buildozer/android/platform/android/platform
# # Create directory /content/.buildozer/android/platform
# # Create directory /content/.buildozer/android/app
# # Check configuration tokens
# # Run ['/usr/bin/python3', '-m', 'pythonforandroid.toolchain', 'clean_builds', '--color=always', '--storage-dir=/content/.buildozer/android/platform/build-arm64-v8a_armeabi-v7a', '--ndk-api=23', '--hook=/content/camerax_provider/gradle_options.py', '--ignore-setup-py', '--debug']
# # Cwd /content/.buildozer/android/platform/python-for-android
# Traceback (most recent call last):
#   File "/usr/local/bin/buildozer", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/buildozer/scripts/client.py", line 13, in main
#     Buildozer().run_command(sys.argv[1:])
#   File "/usr/local/lib/python3.10/dist-packages/buildozer/__init__.py", line 1024, in run_command
#     self.target.run_commands(args)
#   File "/usr/local/lib/python3.10/dist-packages/buildozer/target.py", line 93, in run_commands
#     func(args)
#   File "/usr/local/lib/python3.10/dist-packages/buildozer/targets/android.py", line 999, in cmd_clean
#     self._p4a(["clean_builds"])
#   File "/usr/local/lib/python3.10/dist-packages/buildozer/targets/android.py", line 133, in _p4a
#     return self.buildozer.cmd([*self._p4a_cmd, *cmd, *self.extra_p4a_args], **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/buildozer/__init__.py", line 289, in cmd
#     process = Popen(command, **kwargs)
#   File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: '/content/.buildozer/android/platform/python-for-android'

# %%
# !yes | buildozer init
# Out:
# # Check configuration tokens
# Buildozer is running as root!
# This is not recommended, and may lead to problems later.
# Are you sure you want to continue [y/n]? ERROR: You already have a buildozer.spec file.

# %%
# !yes | buildozer -v android debug
# Out:
# Streaming output truncated to the last 5000 lines.
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/__about__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/_compat.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/_structures.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/_typing.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/markers.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/requirements.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/specifiers.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/tags.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/utils.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/packaging/version.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/_vendor/pyparsing.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/archive_util.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/build_meta.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/alias.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/bdist_egg.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/bdist_rpm.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/bdist_wininst.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/build_clib.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/build_ext.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/build_py.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/develop.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/dist_info.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/easy_install.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/egg_info.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/install.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/install_egg_info.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/install_lib.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/install_scripts.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/py36compat.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/register.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/rotate.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/saveopts.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/sdist.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/setopt.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/test.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/upload.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/command/upload_docs.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/config.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/dep_util.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/depends.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/dist.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/errors.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/extension.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/extern'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/extern/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/glob.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/installer.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/launch.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/lib2to3_ex.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/monkey.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/msvc.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/namespaces.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/package_index.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/py34compat.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/sandbox.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/ssl_support.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/unicode_utils.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/version.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/wheel.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools/windows_support.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/setuptools-51.3.3-py3.9.egg-info'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/sh-2.0.4.dist-info'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/sh.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/share'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/share/doc'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/share/doc/jwcrypto'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/six.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/_collections.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/_version.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/connection.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/connectionpool.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/_appengine_environ.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/_securetransport'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/_securetransport/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/_securetransport/bindings.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/_securetransport/low_level.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/appengine.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/ntlmpool.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/pyopenssl.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/securetransport.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/contrib/socks.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/exceptions.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/fields.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/filepost.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/packages'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/packages/__init__.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/packages/backports'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/packages/backports/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/packages/backports/makefile.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/packages/six.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/poolmanager.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/request.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/response.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/connection.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/proxy.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/queue.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/request.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/response.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/retry.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/ssl_.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/ssl_match_hostname.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/ssltransport.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/timeout.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/url.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3/util/wait.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/urllib3-1.26.12.dist-info'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/usr'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/usr/local'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/usr/local/bin'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/wrapt'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/wrapt/__init__.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/wrapt/arguments.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/wrapt/decorators.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/wrapt/importer.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/wrapt/wrappers.py'...
# Listing '/content/.buildozer/android/platform/build-armeabi-v7a/build/python-installs/Electora/armeabi-v7a/wrapt-1.15.0.dist-info'...
# [INFO]:    Copy 63 files into the bundle
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/parser.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/mmap.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/fcntl.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_testinternalcapi.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_hashlib.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/math.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_sqlite3.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_blake2.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_zoneinfo.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_asyncio.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_datetime.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_multiprocessing.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_ctypes.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_bisect.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_sha3.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_posixsubprocess.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_lsprof.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_codecs_cn.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_testbuffer.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_xxtestfuzz.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_multibytecodec.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_codecs_tw.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/binascii.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_contextvars.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/xxlimited.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/unicodedata.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_elementtree.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/cmath.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_json.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/syslog.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/resource.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_statistics.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_opcode.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/select.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_ctypes_test.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_decimal.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_codecs_hk.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_queue.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_ssl.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_testmultiphase.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_codecs_jp.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/ossaudiodev.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/termios.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_codecs_kr.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/audioop.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_random.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_sha256.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_csv.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_testimportmultiple.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_xxsubinterpreters.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/pyexpat.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_heapq.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_codecs_iso2022.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_testcapi.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_pickle.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_struct.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_sha512.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/array.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/zlib.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_md5.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_socket.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_sha1.cpython-39.so
# [INFO]:     - copy /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/android-build/build/lib.linux-arm-3.9/_sysconfigdata__linux_arm-linux-androideabi.pyc
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_23/python3/Lib
# [INFO]:    Zip 579 files into the bundle
# stty: 'standard input': Inappropriate ioctl for device
# [DEBUG]:   -> running zip -X /content/.buildozer/android/platform/build-armeabi-v7a/dists/Electora/_python_bundle__armeabi-v7a/_python_bundle/stdlib.zip ./types.pyc ./rlcompleter.pyc ./turtle.pyc ./operator.pyc ./xdrlib.pyc ./_pydecimal.pyc ./mimetypes.pyc ./dis.pyc ./compileall.pyc ./mailbox.pyc ./trace.pyc ./re.pyc ./_strptime.pyc ./antigravity.pyc ./shelve.pyc ./lzma.pyc ./gettext.pyc ./pickletools.pyc ./cProfile.pyc ./doctest.pyc ./bisect.pyc ./pickle.pyc ./abc.pyc ./zipfile.pyc ./signal.pyc ./tabnanny.pyc ./struct.pyc ./codeop.pyc ./codecs.pyc ./opcode.pyc ./_sitebuiltins.pyc ./__phello__.foo.pyc ./chunk.pyc ./token.pyc ./pstats.pyc ./ast.pyc ./os.pyc ./py_compile.pyc ./smtpd.pyc ./_pyio.pyc ./cgitb.pyc ./weakref.pyc ./getpass.pyc ./site.pyc ./_weakrefset.pyc ./sre_parse.pyc ./sndhdr.pyc ./ftplib.pyc ./pipes.pyc ./zipapp.pyc ./filecmp.pyc ./mailcap.pyc ./glob.pyc ./pprint.pyc ./statistics.pyc ./optparse.pyc ./_collections_abc.pyc ./genericpath.pyc ./io.pyc ./functools.pyc ./string.pyc ./imghdr.pyc ./configparser.pyc ./bz2.pyc ./sre_constants.pyc ./fractions.pyc ./imp.pyc ./csv.pyc ./posixpath.pyc ./sre_compile.pyc ./pathlib.pyc ./asyncore.pyc ./tarfile.pyc ./timeit.pyc ./heapq.pyc ./telnetlib.pyc ./locale.pyc ./hashlib.pyc ./_threading_local.pyc ./_compat_pickle.pyc ./stat.pyc ./graphlib.pyc ./site.py.orig ./__future__.pyc ./sysconfig.pyc ./plistlib.pyc ./colorsys.pyc ./tracemalloc.pyc ./contextlib.pyc ./copy.pyc ./this.pyc ./pyclbr.pyc ./asynchat.pyc ./argparse.pyc ./hmac.pyc ./gzip.pyc ./_bootlocale.pyc ./nturl2path.pyc ./_bootsubprocess.pyc ./code.pyc ./netrc.pyc ./bdb.pyc ./shlex.pyc ./symbol.pyc ./decimal.pyc ./platform.pyc ./ipaddress.pyc ./_osx_support.pyc ./symtable.pyc ./sunau.pyc ./binhex.pyc ./linecache.pyc ./stringprep.pyc ./dataclasses.pyc ./datetime.pyc ./getopt.pyc ./_py_abc.pyc ./typing.pyc ./warnings.pyc ./socket.pyc ./calendar.pyc ./formatter.pyc ./base64.pyc ./tokenize.pyc ./traceback.pyc ./wave.pyc ./socketserver.pyc ./numbers.pyc ./contextvars.pyc ./pydoc.pyc ./keyword.pyc ./smtplib.pyc ./tty.pyc ./nntplib.pyc ./difflib.pyc ./pdb.pyc ./ntpath.pyc ./threading.pyc ./pty.pyc ./tempfile.pyc ./_aix_support.pyc ./enum.pyc ./shutil.pyc ./subprocess.pyc ./pkgutil.pyc ./aifc.pyc ./random.pyc ./poplib.pyc ./textwrap.pyc ./quopri.pyc ./zipimport.pyc ./runpy.pyc ./modulefinder.pyc ./fnmatch.pyc ./selectors.pyc ./sched.pyc ./copyreg.pyc ./webbrowser.pyc ./_compression.pyc ./_markupbase.pyc ./crypt.pyc ./fileinput.pyc ./uuid.pyc ./ssl.pyc ./profile.pyc ./cmd.pyc ./secrets.pyc ./reprlib.pyc ./queue.pyc ./imaplib.pyc ./uu.pyc ./inspect.pyc ./cgi.pyc ./json/scanner.pyc ./json/encoder.pyc ./json/__init__.pyc ./json/decoder.pyc ./json/tool.pyc ./logging/config.pyc ./logging/handlers.pyc ./logging/__init__.pyc ./turtledemo/lindenmayer.pyc ./turtledemo/rosette.pyc ./turtledemo/penrose.pyc ./turtledemo/turtle.cfg ./turtledemo/tree.pyc ./turtledemo/nim.pyc ./turtledemo/chaos.pyc ./turtledemo/forest.pyc ./turtledemo/paint.pyc ./turtledemo/sorting_animate.pyc ./turtledemo/two_canvases.pyc ./turtledemo/clock.pyc ./turtledemo/minimal_hanoi.pyc ./turtledemo/planet_and_moon.pyc ./turtledemo/fractalcurves.pyc ./turtledemo/__init__.pyc ./turtledemo/colormixer.pyc ./turtledemo/round_dance.pyc ./turtledemo/yinyang.pyc ./turtledemo/__main__.pyc ./turtledemo/peace.pyc ./turtledemo/bytedesign.pyc ./sqlite3/dbapi2.pyc ./sqlite3/__init__.pyc ./sqlite3/dump.pyc ./email/policy.pyc ./email/_parseaddr.pyc ./email/parser.pyc ./email/iterators.pyc ./email/generator.pyc ./email/errors.pyc ./email/header.pyc ./email/encoders.pyc ./email/_header_value_parser.pyc ./email/architecture.rst ./email/quoprimime.pyc ./email/__init__.pyc ./email/message.pyc ./email/utils.pyc ./email/base64mime.pyc ./email/_policybase.pyc ./email/_encoded_words.pyc ./email/headerregistry.pyc ./email/charset.pyc ./email/feedparser.pyc ./email/contentmanager.pyc ./email/mime/text.pyc ./email/mime/audio.pyc ./email/mime/image.pyc ./email/mime/base.pyc ./email/mime/__init__.py ...
# [DEBUG]:   	  adding: types.pyc (deflated 54%)
# [DEBUG]:   	  adding: rlcompleter.pyc (deflated 41%)
# [DEBUG]:   	  adding: turtle.pyc (deflated 58%)
# [DEBUG]:   	  adding: operator.pyc (deflated 64%)
# [DEBUG]:   	  adding: xdrlib.pyc (deflated 62%)
# [DEBUG]:   	  adding: _pydecimal.pyc (deflated 60%)
# [DEBUG]:   	  adding: mimetypes.pyc (deflated 52%)
# [DEBUG]:   	  adding: dis.pyc (deflated 48%)
# [DEBUG]:   	  adding: compileall.pyc (deflated 44%)
# [DEBUG]:   	  adding: mailbox.pyc (deflated 62%)
# [DEBUG]:   	  adding: trace.pyc (deflated 50%)
# [DEBUG]:   	  adding: re.pyc (deflated 49%)
# [DEBUG]:   	  adding: _strptime.pyc (deflated 49%)
# [DEBUG]:   	  adding: antigravity.pyc (deflated 31%)
# [DEBUG]:   	  adding: shelve.pyc (deflated 58%)
# [DEBUG]:   	  adding: lzma.pyc (deflated 51%)
# [DEBUG]:   	  adding: gettext.pyc (deflated 55%)
# [DEBUG]:   	  adding: pickletools.pyc (deflated 67%)
# [DEBUG]:   	  adding: cProfile.pyc (deflated 46%)
# [DEBUG]:   	  adding: doctest.pyc (deflated 55%)
# [DEBUG]:   	  adding: bisect.pyc (deflated 46%)
# [DEBUG]:   	  adding: pickle.pyc (deflated 59%)
# [DEBUG]:   	  adding: abc.pyc (deflated 56%)
# [DEBUG]:   	  adding: zipfile.pyc (deflated 54%)
# [DEBUG]:   	  adding: signal.pyc (deflated 53%)
# [DEBUG]:   	  adding: tabnanny.pyc (deflated 48%)
# [DEBUG]:   	  adding: struct.pyc (deflated 29%)
# [DEBUG]:   	  adding: codeop.pyc (deflated 47%)
# [DEBUG]:   	  adding: codecs.pyc (deflated 65%)
# [DEBUG]:   	  adding: opcode.pyc (deflated 52%)
# [DEBUG]:   	  adding: _sitebuiltins.pyc (deflated 48%)
# [DEBUG]:   	  adding: __phello__.foo.pyc (deflated 26%)
# [DEBUG]:   	  adding: chunk.pyc (deflated 48%)
# [DEBUG]:   	  adding: token.pyc (deflated 42%)
# [DEBUG]:   	  adding: pstats.pyc (deflated 55%)
# [DEBUG]:   	  adding: ast.pyc (deflated 60%)
# [DEBUG]:   	  adding: os.pyc (deflated 54%)
# [DEBUG]:   	  adding: py_compile.pyc (deflated 43%)
# [DEBUG]:   	  adding: smtpd.pyc (deflated 58%)
# [DEBUG]:   	  adding: _pyio.pyc (deflated 61%)
# [DEBUG]:   	  adding: cgitb.pyc (deflated 47%)
# [DEBUG]:   	  adding: weakref.pyc (deflated 62%)
# [DEBUG]:   	  adding: getpass.pyc (deflated 40%)
# [DEBUG]:   	  adding: site.pyc (deflated 49%)
# [DEBUG]:   	  adding: _weakrefset.pyc (deflated 64%)
# [DEBUG]:   	  adding: sre_parse.pyc (deflated 52%)
# [DEBUG]:   	  adding: sndhdr.pyc (deflated 50%)
# [DEBUG]:   	  adding: ftplib.pyc (deflated 53%)
# [DEBUG]:   	  adding: pipes.pyc (deflated 53%)
# [DEBUG]:   	  adding: zipapp.pyc (deflated 43%)
# [DEBUG]:   	  adding: filecmp.pyc (deflated 51%)
# [DEBUG]:   	  adding: mailcap.pyc (deflated 44%)
# [DEBUG]:   	  adding: glob.pyc (deflated 49%)
# [DEBUG]:   	  adding: pprint.pyc (deflated 56%)
# [DEBUG]:   	  adding: statistics.pyc (deflated 54%)
# [DEBUG]:   	  adding: optparse.pyc (deflated 60%)
# [DEBUG]:   	  adding: _collections_abc.pyc (deflated 67%)
# [DEBUG]:   	  adding: genericpath.pyc (deflated 52%)
# [DEBUG]:   	  adding: io.pyc (deflated 45%)
# [DEBUG]:   	  adding: functools.pyc (deflated 56%)
# [DEBUG]:   	  adding: string.pyc (deflated 48%)
# [DEBUG]:   	  adding: imghdr.pyc (deflated 54%)
# [DEBUG]:   	  adding: configparser.pyc (deflated 59%)
# [DEBUG]:   	  adding: bz2.pyc (deflated 54%)
# [DEBUG]:   	  adding: sre_constants.pyc (deflated 55%)
# [DEBUG]:   	  adding: fractions.pyc (deflated 56%)
# [DEBUG]:   	  adding: imp.pyc (deflated 48%)
# [DEBUG]:   	  adding: csv.pyc (deflated 51%)
# [DEBUG]:   	  adding: posixpath.pyc (deflated 50%)
# [DEBUG]:   	  adding: sre_compile.pyc (deflated 50%)
# [DEBUG]:   	  adding: pathlib.pyc (deflated 60%)
# [DEBUG]:   	  adding: asyncore.pyc (deflated 56%)
# [DEBUG]:   	  adding: tarfile.pyc (deflated 54%)
# [DEBUG]:   	  adding: timeit.pyc (deflated 42%)
# [DEBUG]:   	  adding: heapq.pyc (deflated 55%)
# [DEBUG]:   	  adding: telnetlib.pyc (deflated 52%)
# [DEBUG]:   	  adding: locale.pyc (deflated 54%)
# [DEBUG]:   	  adding: hashlib.pyc (deflated 48%)
# [DEBUG]:   	  adding: _threading_local.pyc (deflated 50%)
# [DEBUG]:   	  adding: _compat_pickle.pyc (deflated 51%)
# [DEBUG]:   	  adding: stat.pyc (deflated 56%)
# [DEBUG]:   	  adding: graphlib.pyc (deflated 49%)
# [DEBUG]:   	  adding: site.py.orig (deflated 69%)
# [DEBUG]:   	  adding: __future__.pyc (deflated 51%)
# [DEBUG]:   	  adding: sysconfig.pyc (deflated 48%)
# [DEBUG]:   	  adding: plistlib.pyc (deflated 54%)
# [DEBUG]:   	  adding: colorsys.pyc (deflated 49%)
# [DEBUG]:   	  adding: tracemalloc.pyc (deflated 62%)
# [DEBUG]:   	  adding: contextlib.pyc (deflated 65%)
# [DEBUG]:   	  adding: copy.pyc (deflated 46%)
# [DEBUG]:   	  adding: this.pyc (deflated 40%)
# [DEBUG]:   	  adding: pyclbr.pyc (deflated 46%)
# [DEBUG]:   	  adding: asynchat.pyc (deflated 54%)
# [DEBUG]:   	  adding: argparse.pyc (deflated 60%)
# [DEBUG]:   	  adding: hmac.pyc (deflated 51%)
# [DEBUG]:   	  adding: gzip.pyc (deflated 54%)
# [DEBUG]:   	  adding: _bootlocale.pyc (deflated 42%)
# [DEBUG]:   	  adding: nturl2path.pyc (deflated 37%)
# [DEBUG]:   	  adding: _bootsubprocess.pyc (deflated 39%)
# [DEBUG]:   	  adding: code.pyc (deflated 47%)
# [DEBUG]:   	  adding: netrc.pyc (deflated 42%)
# [DEBUG]:   	  adding: bdb.pyc (deflated 56%)
# [DEBUG]:   	  adding: shlex.pyc (deflated 48%)
# [DEBUG]:   	  adding: symbol.pyc (deflated 46%)
# [DEBUG]:   	  adding: decimal.pyc (deflated 33%)
# [DEBUG]:   	  adding: platform.pyc (deflated 48%)
# [DEBUG]:   	  adding: ipaddress.pyc (deflated 64%)
# [DEBUG]:   	  adding: _osx_support.pyc (deflated 46%)
# [DEBUG]:   	  adding: symtable.pyc (deflated 63%)
# [DEBUG]:   	  adding: sunau.pyc (deflated 61%)
# [DEBUG]:   	  adding: binhex.pyc (deflated 58%)
# [DEBUG]:   	  adding: linecache.pyc (deflated 42%)
# [DEBUG]:   	  adding: stringprep.pyc (deflated 61%)
# [DEBUG]:   	  adding: dataclasses.pyc (deflated 55%)
# [DEBUG]:   	  adding: datetime.pyc (deflated 61%)
# [DEBUG]:   	  adding: getopt.pyc (deflated 46%)
# [DEBUG]:   	  adding: _py_abc.pyc (deflated 46%)
# [DEBUG]:   	  adding: typing.pyc (deflated 61%)
# [DEBUG]:   	  adding: warnings.pyc (deflated 48%)
# [DEBUG]:   	  adding: socket.pyc (deflated 52%)
# [DEBUG]:   	  adding: calendar.pyc (deflated 61%)
# [DEBUG]:   	  adding: formatter.pyc (deflated 67%)
# [DEBUG]:   	  adding: base64.pyc (deflated 48%)
# [DEBUG]:   	  adding: tokenize.pyc (deflated 45%)
# [DEBUG]:   	  adding: traceback.pyc (deflated 53%)
# [DEBUG]:   	  adding: wave.pyc (deflated 61%)
# [DEBUG]:   	  adding: socketserver.pyc (deflated 62%)
# [DEBUG]:   	  adding: numbers.pyc (deflated 74%)
# [DEBUG]:   	  adding: contextvars.pyc (deflated 28%)
# [DEBUG]:   	  adding: pydoc.pyc (deflated 55%)
# [DEBUG]:   	  adding: keyword.pyc (deflated 31%)
# [DEBUG]:   	  adding: smtplib.pyc (deflated 51%)
# [DEBUG]:   	  adding: tty.pyc (deflated 38%)
# [DEBUG]:   	  adding: nntplib.pyc (deflated 52%)
# [DEBUG]:   	  adding: difflib.pyc (deflated 53%)
# [DEBUG]:   	  adding: pdb.pyc (deflated 54%)
# [DEBUG]:   	  adding: ntpath.pyc (deflated 51%)
# [DEBUG]:   	  adding: threading.pyc (deflated 60%)
# [DEBUG]:   	  adding: pty.pyc (deflated 45%)
# [DEBUG]:   	  adding: tempfile.pyc (deflated 57%)
# [DEBUG]:   	  adding: _aix_support.pyc (deflated 41%)
# [DEBUG]:   	  adding: enum.pyc (deflated 54%)
# [DEBUG]:   	  adding: shutil.pyc (deflated 52%)
# [DEBUG]:   	  adding: subprocess.pyc (deflated 51%)
# [DEBUG]:   	  adding: pkgutil.pyc (deflated 49%)
# [DEBUG]:   	  adding: aifc.pyc (deflated 60%)
# [DEBUG]:   	  adding: random.pyc (deflated 50%)
# [DEBUG]:   	  adding: poplib.pyc (deflated 52%)
# [DEBUG]:   	  adding: textwrap.pyc (deflated 47%)
# [DEBUG]:   	  adding: quopri.pyc (deflated 44%)
# [DEBUG]:   	  adding: zipimport.pyc (deflated 48%)
# [DEBUG]:   	  adding: runpy.pyc (deflated 48%)
# [DEBUG]:   	  adding: modulefinder.pyc (deflated 51%)
# [DEBUG]:   	  adding: fnmatch.pyc (deflated 40%)
# [DEBUG]:   	  adding: selectors.pyc (deflated 59%)
# [DEBUG]:   	  adding: sched.pyc (deflated 53%)
# [DEBUG]:   	  adding: copyreg.pyc (deflated 44%)
# [DEBUG]:   	  adding: webbrowser.pyc (deflated 53%)
# [DEBUG]:   	  adding: _compression.pyc (deflated 51%)
# [DEBUG]:   	  adding: _markupbase.pyc (deflated 54%)
# [DEBUG]:   	  adding: crypt.pyc (deflated 37%)
# [DEBUG]:   	  adding: fileinput.pyc (deflated 54%)
# [DEBUG]:   	  adding: uuid.pyc (deflated 55%)
# [DEBUG]:   	  adding: ssl.pyc (deflated 58%)
# [DEBUG]:   	  adding: profile.pyc (deflated 54%)
# [DEBUG]:   	  adding: cmd.pyc (deflated 48%)
# [DEBUG]:   	  adding: secrets.pyc (deflated 39%)
# [DEBUG]:   	  adding: reprlib.pyc (deflated 53%)
# [DEBUG]:   	  adding: queue.pyc (deflated 60%)
# [DEBUG]:   	  adding: imaplib.pyc (deflated 54%)
# [DEBUG]:   	  adding: uu.pyc (deflated 40%)
# [DEBUG]:   	  adding: inspect.pyc (deflated 54%)
# [DEBUG]:   	  adding: cgi.pyc (deflated 52%)
# [DEBUG]:   	  adding: json/scanner.pyc (deflated 38%)
# [DEBUG]:   	  adding: json/encoder.pyc (deflated 50%)
# [DEBUG]:   	  adding: json/__init__.pyc (deflated 45%)
# [DEBUG]:   	  adding: json/decoder.pyc (deflated 45%)
# [DEBUG]:   	  adding: json/tool.pyc (deflated 39%)
# [DEBUG]:   	  adding: logging/config.pyc (deflated 53%)
# [DEBUG]:   	  adding: logging/handlers.pyc (deflated 56%)
# [DEBUG]:   	  adding: logging/__init__.pyc (deflated 60%)
# [DEBUG]:   	  adding: turtledemo/lindenmayer.pyc (deflated 49%)
# [DEBUG]:   	  adding: turtledemo/rosette.pyc (deflated 36%)
# [DEBUG]:   	  adding: turtledemo/penrose.pyc (deflated 53%)
# [DEBUG]:   	  adding: turtledemo/turtle.cfg (deflated 27%)
# [DEBUG]:   	  adding: turtledemo/tree.pyc (deflated 38%)
# [DEBUG]:   	  adding: turtledemo/nim.pyc (deflated 52%)
# [DEBUG]:   	  adding: turtledemo/chaos.pyc (deflated 48%)
# [DEBUG]:   	  adding: turtledemo/forest.pyc (deflated 44%)
# [DEBUG]:   	  adding: turtledemo/paint.pyc (deflated 40%)
# [DEBUG]:   	  adding: turtledemo/sorting_animate.pyc (deflated 55%)
# [DEBUG]:   	  adding: turtledemo/two_canvases.pyc (deflated 36%)
# [DEBUG]:   	  adding: turtledemo/clock.pyc (deflated 44%)
# [DEBUG]:   	  adding: turtledemo/minimal_hanoi.pyc (deflated 44%)
# [DEBUG]:   	  adding: turtledemo/planet_and_moon.pyc (deflated 47%)
# [DEBUG]:   	  adding: turtledemo/fractalcurves.pyc (deflated 49%)
# [DEBUG]:   	  adding: turtledemo/__init__.pyc (deflated 24%)
# [DEBUG]:   	  adding: turtledemo/colormixer.pyc (deflated 43%)
# [DEBUG]:   	  adding: turtledemo/round_dance.pyc (deflated 33%)
# [DEBUG]:   	  adding: turtledemo/yinyang.pyc (deflated 42%)
# [DEBUG]:   	  adding: turtledemo/__main__.pyc (deflated 48%)
# [DEBUG]:   	  adding: turtledemo/peace.pyc (deflated 39%)
# [DEBUG]:   	  adding: turtledemo/bytedesign.pyc (deflated 58%)
# [DEBUG]:   	  adding: sqlite3/dbapi2.pyc (deflated 51%)
# [DEBUG]:   	  adding: sqlite3/__init__.pyc (deflated 22%)
# [DEBUG]:   	  adding: sqlite3/dump.pyc (deflated 42%)
# [DEBUG]:   	  adding: email/policy.pyc (deflated 44%)
# [DEBUG]:   	  adding: email/_parseaddr.pyc (deflated 53%)
# [DEBUG]:   	  adding: email/parser.pyc (deflated 55%)
# [DEBUG]:   	  adding: email/iterators.pyc (deflated 40%)
# [DEBUG]:   	  adding: email/generator.pyc (deflated 51%)
# [DEBUG]:   	  adding: email/errors.pyc (deflated 66%)
# [DEBUG]:   	  adding: email/header.pyc (deflated 50%)
# [DEBUG]:   	  adding: email/encoders.pyc (deflated 44%)
# [DEBUG]:   	  adding: email/_header_value_parser.pyc (deflated 65%)
# [DEBUG]:   	  adding: email/architecture.rst (deflated 64%)
# [DEBUG]:   	  adding: email/quoprimime.pyc (deflated 45%)
# [DEBUG]:   	  adding: email/__init__.pyc (deflated 52%)
# [DEBUG]:   	  adding: email/message.pyc (deflated 56%)
# [DEBUG]:   	  adding: email/utils.pyc (deflated 43%)
# [DEBUG]:   	  adding: email/base64mime.pyc (deflated 36%)
# [DEBUG]:   	  adding: email/_policybase.pyc (deflated 52%)
# [DEBUG]:   	  adding: email/_encoded_words.pyc (deflated 44%)
# [DEBUG]:   	  adding: email/headerregistry.pyc (deflated 62%)
# [DEBUG]:   	  adding: email/charset.pyc (deflated 49%)
# [DEBUG]:   	  adding: email/feedparser.pyc (deflated 52%)
# [DEBUG]:   	  adding: email/contentmanager.pyc (deflated 49%)
# [DEBUG]:   	  adding: email/mime/text.pyc (deflated 34%)
# [DEBUG]:   	  adding: email/mime/audio.pyc (deflated 36%)
# [DEBUG]:   	  adding: email/mime/image.pyc (deflated 35%)
# [DEBUG]:   	  adding: email/mime/base.pyc (deflated 34%)
# [DEBUG]:   	  adding: email/mime/__init__.pyc (deflated 25%)
# [DEBUG]:   	  adding: email/mime/message.pyc (deflated 35%)
# [DEBUG]:   	  adding: email/mime/multipart.pyc (deflated 34%)
# [DEBUG]:   	  adding: email/mime/application.pyc (deflated 37%)
# [DEBUG]:   	  adding: email/mime/nonmultipart.pyc (deflated 37%)
# [DEBUG]:   	  adding: multiprocessing/queues.pyc (deflated 55%)
# [DEBUG]:   	  adding: multiprocessing/resource_tracker.pyc (deflated 45%)
# [DEBUG]:   	  adding: multiprocessing/resource_sharer.pyc (deflated 52%)
# [DEBUG]:   	  adding: multiprocessing/sharedctypes.pyc (deflated 54%)
# [DEBUG]:   	  adding: multiprocessing/reduction.pyc (deflated 49%)
# [DEBUG]:   	  adding: multiprocessing/popen_spawn_posix.pyc (deflated 44%)
# [DEBUG]:   	  adding: multiprocessing/popen_spawn_win32.pyc (deflated 42%)
# [DEBUG]:   	  adding: multiprocessing/shared_memory.pyc (deflated 53%)
# [DEBUG]:   	  adding: multiprocessing/forkserver.pyc (deflated 45%)
# [DEBUG]:   	  adding: multiprocessing/context.pyc (deflated 64%)
# [DEBUG]:   	  adding: multiprocessing/process.pyc (deflated 54%)
# [DEBUG]:   	  adding: multiprocessing/managers.pyc (deflated 59%)
# [DEBUG]:   	  adding: multiprocessing/util.pyc (deflated 50%)
# [DEBUG]:   	  adding: multiprocessing/__init__.pyc (deflated 31%)
# [DEBUG]:   	  adding: multiprocessing/heap.pyc (deflated 50%)
# [DEBUG]:   	  adding: multiprocessing/popen_fork.pyc (deflated 48%)
# [DEBUG]:   	  adding: multiprocessing/connection.pyc (deflated 54%)
# [DEBUG]:   	  adding: multiprocessing/synchronize.pyc (deflated 58%)
# [DEBUG]:   	  adding: multiprocessing/popen_forkserver.pyc (deflated 42%)
# [DEBUG]:   	  adding: multiprocessing/pool.pyc (deflated 57%)
# [DEBUG]:   	  adding: multiprocessing/spawn.pyc (deflated 45%)
# [DEBUG]:   	  adding: multiprocessing/dummy/__init__.pyc (deflated 49%)
# ...
# [DEBUG]:   Dist matching name and arch: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [DEBUG]:   Dist matching ndk_api and recipe: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	Electora: min API 23, includes recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests), built for archs (armeabi-v7a)
# [INFO]:    Electora has compatible recipes, using this one
# [DEBUG]:   All possible dists: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [DEBUG]:   Dist matching name and arch: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [DEBUG]:   Dist matching ndk_api and recipe: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	Electora: min API 23, includes recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests), built for archs (armeabi-v7a)
# [INFO]:    Electora has compatible recipes, using this one
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-armeabi-v7a/build/bootstrap_builds/sdl2
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [INFO]:    -> directory context /content/.buildozer/android/platform/build-armeabi-v7a/dists/Electora
# [INFO]:    Hook: execute before_apk_build
# [INFO]:    Camerax Provider: Add android.permissions = CAMERA
# [INFO]:    Camerax Provider: Add android.permissions = RECORD_AUDIO
# [INFO]:    Camerax Provider: Add android.gradle_dependencies reqired for CameraX
# [INFO]:    Camerax Provider: Add android.add_src = ./camerax_provider/camerax_src
# Compiling '/content/.buildozer/android/app/db.py'...
# Compiling '/content/.buildozer/android/app/main.py'...
# Compiling '/content/.buildozer/android/app/sitecustomize.py'...
# Compiling '/content/.buildozer/android/app/backend.py'...
# Compiling '/content/.buildozer/android/app/camerax_provider/gradle_options.py'...
# [INFO]:    Hook: ignore after_apk_build
# [INFO]:    Hook: ignore before_apk_assemble
# [INFO]:    Detected highest available build tools version to be 34.0.0
# stty: 'standard input': Inappropriate ioctl for device
# [DEBUG]:   -> running gradlew clean assembleDebug
# [DEBUG]:
# [DEBUG]:   	<-------------> 0% INITIALIZING s]
# [DEBUG]:   	<-------------> 0% CONFIGURING s]> root project<-------------> 0% CONFIGURING s]> root project > Resolve dependencies of :classpath<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]<-------------> 0% CONFIGURING s]> root project > Resolve files of :classpath<-------------> 0% CONFIGURING s]> root project<-------------> 0% CONFIGURING s]
# [DEBUG]:   	> Configure project :
# [DEBUG]:   	WARNING:Using flatDir should be avoided because it doesn't support any meta-data formats.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<=============> 100% CONFIGURING s]> IDLEWARNING:We recommend using a newer Android Gradle plugin to use compileSdk = 33
# [DEBUG]:
# [DEBUG]:   	This Android Gradle plugin (7.1.2) was tested up to compileSdk = 32
# [DEBUG]:
# [DEBUG]:   	This warning can be suppressed by adding
# [DEBUG]:   	    android.suppressUnsupportedCompileSdk=33
# [DEBUG]:   	to this project's gradle.properties
# [DEBUG]:
# [DEBUG]:   	The build will continue, but you are strongly encouraged to update your project to
# [DEBUG]:   	use a newer Android Gradle Plugin that has been tested with compileSdk = 33
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<=============> 100% CONFIGURING s]> IDLE<=============> 100% CONFIGURING [1s]<==-----------> 19% EXECUTING [1s]> :checkDebugAarMetadata > Resolve dependencies of :debugRuntimeClasspath<===----------> 26% EXECUTING [1s]> :mergeDebugResources
# [DEBUG]:   	<====---------> 31% EXECUTING [1s]> :processDebugMainManifest
# [DEBUG]:   	> Task :processDebugMainManifest
# [DEBUG]:   	/content/.buildozer/android/platform/build-armeabi-v7a/dists/Electora/src/main/AndroidManifest.xml:39:9-69 Warning:
# [DEBUG]:   	        Element uses-permission#android.permission.CAMERA at AndroidManifest.xml:39:9-69 duplicated with element declared at AndroidManifest.xml:31:9-69
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<====---------> 34% EXECUTING [1s]> :mergeDebugResources> :processDebugManifest<======-------> 46% EXECUTING [1s]> :mergeDebugAssets<======-------> 51% EXECUTING [1s]> IDLE> :compressDebugAssets<======-------> 53% EXECUTING [2s]> :processDebugResources> IDLE> :processDebugResources > Resolve dependencies of :debugCompileClasspath> :processDebugResources<=======------> 56% EXECUTING [2s]> :mergeDebugJavaResource<=======------> 60% EXECUTING [2s]> :desugarDebugFileDependencies<=======------> 60% EXECUTING [3s]<========-----> 63% EXECUTING [3s]> IDLE<========-----> 65% EXECUTING [3s]> :compileDebugJavaWithJavac<========-----> 65% EXECUTING [4s]<========-----> 65% EXECUTING [5s]<========-----> 65% EXECUTING [6s]<========-----> 65% EXECUTING [7s]
# [DEBUG]:   	> Task :compileDebugJavaWithJavac
# [DEBUG]:   	Note: Some input files use or override a deprecated API.
# [DEBUG]:   	Note: Recompile with -Xlint:deprecation for details.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<========-----> 65% EXECUTING [7s]> IDLE> :compileDebugJavaWithJavac<========-----> 68% EXECUTING [7s]> :mergeExtDexDebug > Resolve files of :debugRuntimeClasspath<========-----> 68% EXECUTING [8s]> :mergeLibDexDebug> :mergeExtDexDebug<========-----> 68% EXECUTING [9s]<========-----> 68% EXECUTING [10s]<========-----> 68% EXECUTING [11s]<=========----> 73% EXECUTING [12s]> :dexBuilderDebug> IDLE<=========----> 73% EXECUTING [13s]<=========----> 73% EXECUTING [14s]<=========----> 75% EXECUTING [14s]> :mergeProjectDexDebug> :mergeDebugJniLibFolders<=========----> 75% EXECUTING [15s]<==========---> 78% EXECUTING [15s]> IDLE<==========---> 80% EXECUTING [15s]> :validateSigningDebug> :mergeDebugNativeLibs<===========--> 87% EXECUTING [15s]> IDLE<===========--> 90% EXECUTING [15s]> :stripDebugDebugSymbols
# [DEBUG]:   	> Task :stripDebugDebugSymbols
# [DEBUG]:   	Unable to strip the following libraries, packaging them as they are: libSDL2.so, libSDL2_image.so, libSDL2_mixer.so, libSDL2_ttf.so, libcrypto1.1.so, libffi.so, libfreetype.so, libimage_processing_util_jni.so, libmain.so, libpng16.so, libpybundle.so, libpython3.9.so, libsqlite3.so, libssl1.1.so.
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<============-> 92% EXECUTING [15s]> IDLE> :packageDebug<============-> 92% EXECUTING [16s]<============-> 92% EXECUTING [17s]
# [DEBUG]:   	Deprecated Gradle features were used in this build, making it incompatible with Gradle 8.0.
# [DEBUG]:
# [DEBUG]:   	You can use '--warning-mode all' to show the individual deprecation warnings and determine if they come from your own scripts or plugins.
# [DEBUG]:
# [DEBUG]:   	See https://docs.gradle.org/7.4.1/userguide/command_line_interface.html#sec:command_line_warnings
# [DEBUG]:
# [DEBUG]:   	BUILD SUCCESSFUL in 18s
# [DEBUG]:   	31 actionable tasks: 30 executed, 1 up-to-date
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:
# [DEBUG]:   	<-------------> 0% WAITING> IDLE> :packageDebug
# [INFO]:    <- directory context /content/.buildozer/android/platform/python-for-android
# [DEBUG]:   All possible dists: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [DEBUG]:   Dist matching name and arch: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [DEBUG]:   Dist matching ndk_api and recipe: [<Distribution: name Electora with recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests)>]
# [INFO]:    Of the existing distributions, the following meet the given requirements:
# [INFO]:    	Electora: min API 23, includes recipes (freetype, hostpython3, jpeg, libffi, openssl, png, sdl2_image, sdl2_mixer, sdl2_ttf, sqlite3, python3, sdl2, setuptools, decorator, pillow, pycparser, six, cffi, pyjnius, android, cryptography, kivy, pycryptodome, jws, urllib3, wrapt, camera4kivy, chardet, python-jwt, requests-toolbelt, platformdirs, pyrebase4, gcloud, distlib, filelock, pyasn1, pygments, oauth2client, click, jwcrypto, pexpect, idna, certifi, sh, rsa, future, docutils, backports.entry-points-selectable, gestures4kivy, pyasn1-modules, ratelim, httplib2, kivymd, dnspython, pyparsing, geocoder, googleapis-common-protos, appengine-python-standard, ptyprocess, protobuf, deprecated, requests), built for archs (armeabi-v7a)
# [INFO]:    Electora has compatible recipes, using this one
# [INFO]:    Hook: ignore after_apk_assemble
# [INFO]:    # Copying android package to current directory
# [INFO]:    # Android package filename not found in build output. Guessing...
# [INFO]:    # Found android package file: /content/.buildozer/android/platform/build-armeabi-v7a/dists/Electora/build/outputs/apk/debug/Electora-debug.apk
# [INFO]:    # Add version number to android package
# [INFO]:    # Android package renamed to Electora-debug-1.0.apk
# stty: 'standard input': Inappropriate ioctl for device
# [DEBUG]:   -> running cp /content/.buildozer/android/platform/build-armeabi-v7a/dists/Electora/build/outputs/apk/debug/Electora-debug.apk Electora-debug-1.0.apk
# WARNING: Received a --sdk argument, but this argument is deprecated and does nothing.
# No setup.py/pyproject.toml used, copying full private data into .apk.
# Applying Java source code patches...
# Applying patch: src/patches/SDLActivity.java.patch
# # Android packaging done!
# # APK Electora-1.0-armeabi-v7a-debug.apk available in the bin directory

# %%
'''!unzip /content/Electora.zip -d /content/'''
# Out:
# '!unzip /content/Electora.zip -d /content/'
